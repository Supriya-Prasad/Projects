# %% [markdown]
# Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title-2.png](attachment:2-title-2.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:3-intro.png)

# %% [markdown]
# **Objectives:**
# * List some of the popular languages that data scientists use.
# * List some of the commonly used libraries that data scientists use.
# * Provide examples of some arithmatic operations in Python.

# %% [markdown]
# ![10-objectives-2.png](attachment:10-objectives-2.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL (Structured Query Language)
# 4. Java
# 5. Scala
# 6. Julia
# 7. MATLAB
# 8. SAS (Statistical Analysis System)
# 9. JavaScript (for data visualization, with libraries like D3.js)

# %% [markdown]
# ![4-dslanguages.png](attachment:4-dslanguages.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Scikit-learn
# 2. TensorFlow
# 3. Pandas
# 4. Matplotlib
# 5. Seaborn
# 6. Keras
# 7. SciPy
# 8. NLTK

# %% [markdown]
# ![5-dslibraries.png](attachment:5-dslibraries.png)

# %% [markdown]
# | **Data Science Tools**   |
# |-----------------------|
# | Jupyter Notebooks     |
# | RStudio               |
# | VS Code with Python   |

# %% [markdown]
# ![6-dstools.png](attachment:6-dstools.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![7-introarithmetic.png](attachment:7-introarithmetic.png)

# %%
'''This a simple arithmetic expression to mutiply then add integers'''
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:8-multiplyandaddintegers.png)

# %%
'''This will convert 200 minutes to hours by diving by 60'''
print("200 minutes is", 200/60,"hours.")
# Out:
# 200 minutes is 3.3333333333333335 hours.

# %% [markdown]
# ![9-hourstominutes.png](attachment:9-hourstominutes.png)

# %% [markdown]
# ## Author
#
# Supriya Prasad

# %% [markdown]
# ![11-authordetails.png](attachment:11-authordetails.png)
